# %%
import pandas as pd
 
pd.__version__
# Out:
# '2.1.3'

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('FoodPrice_in_Turkey.csv')
df
# Out:
#                  Place  ProductId              ProductName  UmId UmName  \
# 0     National Average         52            Rice - Retail     5     KG
# 1     National Average         52            Rice - Retail     5     KG
# 2     National Average         52            Rice - Retail     5     KG
# 3     National Average         52            Rice - Retail     5     KG
# 4     National Average         52            Rice - Retail     5     KG
# ...                ...        ...                      ...   ...    ...
# 7376             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7377             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7378             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7379             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7380             Izmir        502  Cocoa (powder) - Retail     5     KG
#
#       Month  Year    Price
# 0         5  2013   4.4920
# 1         6  2013   4.5786
# 2        11  2013   4.7865
# 3        12  2013   5.1337
# 4         1  2014   5.5099
# ...     ...   ...      ...
# 7376      8  2019  47.9040
# 7377      9  2019  49.1176
# 7378     10  2019  50.8347
# 7379     11  2019  51.7985
# 7380     12  2019  51.6071
#
# [7381 rows x 8 columns]

# %%
df = pd.read_csv('FoodPrice_in_Turkey.csv')

# Hiển thị 5 dòng đầu
df.head()
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price
# 0  4.4920
# 1  4.5786
# 2  4.7865
# 3  5.1337
# 4  5.5099

# %%
# Hiển thị 5 dòng cuối
df.tail()
# Out:
#       Place  ProductId              ProductName  UmId UmName  Month  Year  \
# 7376  Izmir        502  Cocoa (powder) - Retail     5     KG      8  2019
# 7377  Izmir        502  Cocoa (powder) - Retail     5     KG      9  2019
# 7378  Izmir        502  Cocoa (powder) - Retail     5     KG     10  2019
# 7379  Izmir        502  Cocoa (powder) - Retail     5     KG     11  2019
# 7380  Izmir        502  Cocoa (powder) - Retail     5     KG     12  2019
#
#         Price
# 7376  47.9040
# 7377  49.1176
# 7378  50.8347
# 7379  51.7985
# 7380  51.6071

# %%
# xem 5 dòng ngẫu nhiên
df.sample(10)
# Out:
#                  Place  ProductId                ProductName  UmId  \
# 6480             Izmir        209  Coffee (instant) - Retail    33
# 3752            Ankara        364            Yogurt - Retail     5
# 4550          Istanbul        112             Pasta - Retail     5
# 3131            Ankara        151            Coffee - Retail     5
# 7165             Izmir        450          Zucchini - Retail     5
# 4158            Ankara        493             Water - Retail   100
# 2642            Ankara         52              Rice - Retail     5
# 786   National Average        124    Bread (common) - Retail     5
# 5893             Izmir         66     Beans (white) - Retail     5
# 4780          Istanbul        183     Meat (mutton) - Retail     5
#
#            UmName  Month  Year    Price
# 6480         Unit     12  2018  61.3502
# 3752           KG     11  2018   5.9377
# 4550           KG     12  2017   3.3305
# 3131           KG      7  2019  45.9746
# 7165           KG      1  2017   5.8478
# 4158  Cubic meter      4  2018   6.7041
# 2642           KG     10  2017   6.9750
# 786            KG     12  2014   2.8550
# 5893           KG     12  2018  12.3734
# 4780           KG      7  2017  50.2302

# %%
# Tổng quát về cấu trúc dữ liệu

    # có bao nhiêu dòng, bao nhiêu cột --> .shape, số dòng: .shape[0], số cột: .shape[1]
    # Bảng có tên từng cột --> .columns
    # Kiểu dữ liệu từng cột (numeric, ngày tháng...) --> .dtypes hoặc .info()

# %%
df.shape
print('Số dòng dữ liệu :', df.shape[0])
print('Số cột dữ liệu :', df.shape[1])
# Out:
# Số dòng dữ liệu : 7381
# Số cột dữ liệu : 8

# %%
df.columns
# Out:
# Index(['Place', 'ProductId', 'ProductName', 'UmId', 'UmName', 'Month', 'Year',
#        'Price'],
#       dtype='object')

# %%
# Xem kiểu dữ liệu cảu bảng

df.dtypes
# Out:
# Place           object
# ProductId        int64
# ProductName     object
# UmId             int64
# UmName          object
# Month            int64
# Year             int64
# Price          float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7381 entries, 0 to 7380
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Place        7381 non-null   object
#  1   ProductId    7381 non-null   int64
#  2   ProductName  7381 non-null   object
#  3   UmId         7381 non-null   int64
#  4   UmName       7381 non-null   object
#  5   Month        7381 non-null   int64
#  6   Year         7381 non-null   int64
#  7   Price        7381 non-null   float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 461.4+ KB

# %%
# Truy cập dòng có chỉ số 3 của dữ liệu ( 0, 1, 2, 3, 4....)

tg = df.iloc[3]
tg
# Out:
# Place          National Average
# ProductId                    52
# ProductName       Rice - Retail
# UmId                          5
# UmName                       KG
# Month                        12
# Year                       2013
# Price                    5.1337
# Name: 3, dtype: object

# %%
# Truy cập các dòng có chỉ số liên tục từ 3 đến 8 của dữ liệu

tg = df.iloc[3:8] # từ 3 đến dòng (8-1)
tg
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
# 5  National Average         52  Rice - Retail     5     KG      2  2014
# 6  National Average         52  Rice - Retail     5     KG      3  2014
# 7  National Average         52  Rice - Retail     5     KG      5  2014
#
#     Price
# 3  5.1337
# 4  5.5099
# 5  5.8146
# 6  6.0014
# 7  6.3202

# %%
# Truy câp các dòng rời rạc của dữ liệu, ví dụ 3,6,8

tg = df.iloc[[3,6,8]]
tg
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 6  National Average         52  Rice - Retail     5     KG      3  2014
# 8  National Average         52  Rice - Retail     5     KG      6  2014
#
#     Price
# 3  5.1337
# 6  6.0014
# 8  6.6019

# %%
# df.iloc[hàng, cột]
# df.iloc[:, cột]
# : được sử dụng để đại diện cho tất cả các dòng

tg = df.iloc[:, 4]
tg
# Out:
# 0       KG
# 1       KG
# 2       KG
# 3       KG
# 4       KG
#         ..
# 7376    KG
# 7377    KG
# 7378    KG
# 7379    KG
# 7380    KG
# Name: UmName, Length: 7381, dtype: object

# %%
# muốn lấy hàng 3, cột 4

tg = df.iloc[3, 4]
tg
# Out:
# 'KG'

# %%
# Truy cập các cột liên tục từ 3 đến 8

tg = df.iloc[:, 3:8]
tg
# Out:
#       UmId UmName  Month  Year    Price
# 0        5     KG      5  2013   4.4920
# 1        5     KG      6  2013   4.5786
# 2        5     KG     11  2013   4.7865
# 3        5     KG     12  2013   5.1337
# 4        5     KG      1  2014   5.5099
# ...    ...    ...    ...   ...      ...
# 7376     5     KG      8  2019  47.9040
# 7377     5     KG      9  2019  49.1176
# 7378     5     KG     10  2019  50.8347
# 7379     5     KG     11  2019  51.7985
# 7380     5     KG     12  2019  51.6071
#
# [7381 rows x 5 columns]

# %%
# lấy giá trị ở cột 3 đến 6  (in đến cột 5)

tg = df.iloc[3:6]
tg
# cho ra kết quả là dòng
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
# 5  National Average         52  Rice - Retail     5     KG      2  2014
#
#     Price
# 3  5.1337
# 4  5.5099
# 5  5.8146

# %%
tg = df.iloc[:, 3:6]
tg
# Out:
#       UmId UmName  Month
# 0        5     KG      5
# 1        5     KG      6
# 2        5     KG     11
# 3        5     KG     12
# 4        5     KG      1
# ...    ...    ...    ...
# 7376     5     KG      8
# 7377     5     KG      9
# 7378     5     KG     10
# 7379     5     KG     11
# 7380     5     KG     12
#
# [7381 rows x 3 columns]

# %%
# lấy giá trị ở hàng 30 cột 5

tg = df.iloc[30, 5]
tg
# Out:
# 4

# %%
# lấy giá trị ở hàng 20 đến 30 (in đến hàng 29), cột 2 đến 5 (in đến cột 4)

df.iloc[20:30,2:5]
# Out:
#       ProductName  UmId UmName
# 20  Rice - Retail     5     KG
# 21  Rice - Retail     5     KG
# 22  Rice - Retail     5     KG
# 23  Rice - Retail     5     KG
# 24  Rice - Retail     5     KG
# 25  Rice - Retail     5     KG
# 26  Rice - Retail     5     KG
# 27  Rice - Retail     5     KG
# 28  Rice - Retail     5     KG
# 29  Rice - Retail     5     KG

# %%
df_price = df.loc[:, 'Price']
