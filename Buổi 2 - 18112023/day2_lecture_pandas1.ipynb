# %% [markdown]
# # Nhập thư viện

# %%
# thư viện để phân tích dữ liệu
import pandas as pd
# thư viện để làm việc với chuỗi và số (numpy: numerical python)
import numpy as np

# thư viện để trực quan hoá dữ liệu
# seaborn
# matplotlib

# thư viện để chạy mô hình dự đoán
# scikit-learn

# %% [markdown]
# # Pandas Components

# %% [markdown]
# Gồm DataFrame và Series

# %% [markdown]
# DataFrame là kiểu dữ liệu hai chiều cho phép lưu trữ dữ liệu của một
# bảng tính.
#
# Series là kiểu dữ liệu một chiều đại diện cho các cột trong DataFrame.

# %% [markdown]
# ## Tạo DataFrame thủ công

# %% [markdown]
# ### Tạo DataFrame rỗng

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Tạo DataFrame từ List

# %% [markdown]
# List là một danh sách biểu diễn một chuỗi các phần tử có kiểu dữ liệu đồng nhất hoặc khác nhau.
#
# Các phần tử được đặt trong cặp dấu ngoặc vuông [] và được ngăn cách nhau bởi dấu phẩy (,)

# %%
# bước 1: tạo danh sách
lst = ['Tiên', 'Hải', 'Hưng', 'Khanh', 'Khánh']
lst
# Out:
# ['Tiên', 'Hải', 'Hưng', 'Khanh', 'Khánh']

# %%
# bước 2: tạo bảng dựa trên danh sách
df = pd.DataFrame(lst)
df
# Out:
#        0
# 0   Tiên
# 1    Hải
# 2   Hưng
# 3  Khanh
# 4  Khánh

# %%
list = ['kế toán', 'Kinh doanh', 'Tiếp thị']
df = pd.DataFrame(list)
df
# Out:
#             0
# 0     kế toán
# 1  Kinh doanh
# 2    Tiếp thị

# %% [markdown]
# ### Tạo DataFrame từ Tuple

# %% [markdown]
# Tuple biểu diễn một chuỗi các phần tử cố định.
#
# Các phần tử được đặt trong cặp dấu ngoặc vuông () và được ngăn cách
# nhau bởi dấu phẩy (,)

# %%
# bước 1: tạo tuple
tuples = [('Kế toán', 2000),('Kinh doanh', 2100), ('Tiếp thị', 1900)]
# bước 2: tạo dataframe
df = pd.DataFrame(tuples, columns=['Nghề','Lương'])
df
# Out:
#          Nghề  Lương
# 0     Kế toán   2000
# 1  Kinh doanh   2100
# 2    Tiếp thị   1900

# %%
# tạo bảng về học viên trong lớp (Tên, Tuổi)
# tuple: (Tiên, 26), (Hải, 27), (Hưng, 20), (Khanh, 21), (Khánh, 22)
tuples = [('Tiên', 26), ('Hải', 27), ('Hưng', 20), ('Khanh', 21), ('Khánh', 22)]
df = pd.DataFrame(tuples, columns=['Tên', 'Tuổi'])
df
# Out:
#      Tên  Tuổi
# 0   Tiên    26
# 1    Hải    27
# 2   Hưng    20
# 3  Khanh    21
# 4  Khánh    22

# %% [markdown]
# ### Tạo DataFrame từ Dictionary

# %% [markdown]
# Dictionary là tập hợp các cặp khóa giá trị theo dạng key:value, key và value được trình bày như một List có thể có kiểu dữ liệu bất kỳ
#
# Dictionary được định nghĩa trong dấu ngoặc nhọn {}, giá trị của key tương ứng với các cột, giá trị của value tương ứng với các dòng.

# %%
# key: khoá
# value: giá trị
# biểu diễn: {}
dic = {'Nghề':['Kế toán','Kinh doanh','Tiếp thị'],
       'Lương':[2000, 2100, 1900]}
df = pd.DataFrame(dic)
df
# Out:
#          Nghề  Lương
# 0     Kế toán   2000
# 1  Kinh doanh   2100
# 2    Tiếp thị   1900

# %%
# tạo dictionary
dic = {'Tên':['Tiên', 'Hải', 'Hưng', 'Khanh', 'Khánh'], 'Tuổi':[26, 27, 20, 21, 22]}
# tạo bảng từ từ điển
df = pd.DataFrame(dic)
df
# Out:
#      Tên  Tuổi
# 0   Tiên    26
# 1    Hải    27
# 2   Hưng    20
# 3  Khanh    21
# 4  Khánh    22

# %% [markdown]
# Tổng kết 1:
#
# Pandas là thư viện nhằm phục vụ việc phân tích dữ liệu trong Python
#
# 2 thành phần chính trong Pandas:
#
# 1. Dataframe (bảng 2 chiều, có hàng có cột)
#
# 2. Series (1 chiều, một trong các cột của dataframe)
#
# Tạo Dataframe thủ công
#
# 1. Tạo bảng rỗng: pd.DataFrame()
# 2. Tạo bảng từ các List, Tuples, Dictionary
#
# list = [a, b, c]
#
# tuple = [(), (), (), ...]
#
# dictionary = {key1:[value1, value2, value3], key2:[....], ...}
#
# pd.DataFrame(list)
#
# pd.DataFrame(tuples)
#
# pd.DataFrame(dictionary)
#
# Thêm tên cột cho bảng
#
# pd.DataFrame(..., columns = [a, b, c])

# %% [markdown]
# ## Tạo Series thủ công

# %% [markdown]
# ### Tạo Series từ Dictionary

# %%
# Khai báo Dictionary:
dict = {0 : 'Kế toán', 1 : 'Kinh doanh', 2 : 'Tiếp thị'}
# Gán giá trị của Dictionary vào Series
seri = pd.Series(dict)
seri
# Out:
# 0       Kế toán
# 1    Kinh doanh
# 2      Tiếp thị
# dtype: object

# %%
dict = {0: 'Tiên', 1: 'Hải', 2: 'Hưng', 3: 'Khánh', 4: 'Khanh', 5: 'Đạt'}
seri = pd.Series(dict)
seri
# Out:
# 0     Tiên
# 1      Hải
# 2     Hưng
# 3    Khánh
# 4    Khanh
# 5      Đạt
# dtype: object

# %% [markdown]
# ### Tạo Series từ Numpy Array

# %%
# Tạo Numpy array
arr = np.array([51,65,48,59,68])
# Gán giá trị của array vào Series
seri = pd.Series(arr)
seri
# Out:
# 0    51
# 1    65
# 2    48
# 3    59
# 4    68
# dtype: int64

# %%
# Tuổi: 26, 27, 20, 21, 22, 23
arr = np.array([26,27,20,21,22,23])
seri = pd.Series(arr)
seri
# Out:
# 0    26
# 1    27
# 2    20
# 3    21
# 4    22
# 5    23
# dtype: int64

# %% [markdown]
# ### Tạo Series từ các giá trị vô hướng

# %%
seri = pd.Series(10, index=[0,1,2,3,4,5])
seri
# Out:
# 0    10
# 1    10
# 2    10
# 3    10
# 4    10
# 5    10
# dtype: int64

# %% [markdown]
# Làm việc với bảng
#
# 1. Thêm cột, xoá cột, gộp cột
#
# 2. Tính toán
#
# 3. Lọc, sắp xếp, nhóm dữ liệu

# %% [markdown]
# Bảng
#
# 1. Một bảng
#
# - Đọc bảng
#
# - Kiểm tra bảng: xem hình thức và nội dung (tóm tắt thông kê)
#
# - Chỉnh sửa cấu trúc
#
# - Thay thế giá trị trong cột, dòng
#
# - Lưu lại bảng (sau khi đã sửa)
#
# - Khác:
#   - Truy cập
#   - Chọn
#   - Lọc
#   - Sắp xếp
#   - Tính toán (cộng trừ nhân chia, lớn nhất, nhỏ nhất, trung bình)
#   - Tổng hợp
#   - pivot table
#
# 2. Hai bảng trở lên
# - Gộp bảng
#   - Gộp dòng
#   - Gộp cột
# - UNION, LEFT JOIN, RIGHT JOIN, INNER JOIN ...

# %% [markdown]
# # Làm việc với DataFrame

# %% [markdown]
# Một số các hoạt động cơ bản của DataFrame:
#
# 1.   Tạo DataFrame từ các nguồn dữ liệu có sẵn (csv, xls, xlsx, json, fdf5, html, vvv.)
#
# 2.   Ghi dữ liệu DataFrame vào các file khác nhau
#
# 3.   Mô tả dữ liệu
#
#     (1) **Cấu trúc** bộ dữ liệu DataFrame (số dòng, số cột, kiểu dữ liệu của các thuộc tính, vvv.)
#
#     (2) **Giá trị thống kê** mô tả của các biến *định tính* và *định lượng*
#
# 4.   Truy cập dữ liệu
# 5.   Chỉnh sửa dữ liệu
#
#      (1) Chỉnh sửa **cấu trúc bộ dữ liệu** (đổi tên cột thuộc tính, thêm bớt số dòng số cột, vvv.)
#
#      (2) Thay thế **giá trị** các ô dữ liệu, vvv.
#
# 6.   Hợp nhất dữ liệu từ nhiều nguồn
# 7.   Tạo bảng tổng hợp pivot table
#
# Trong bài hôm nay, tìm hiểu sâu về 1, 2, 3.1, 4, và 5.1

# %% [markdown]
# ## Tạo DataFrame từ các nguồn dữ liệu có sẵn

# %% [markdown]
# Dữ liệu trong thực tế được thu thập từ rất nhiều nguồn với các định dạng
# khác nhau.
#
# Pandas cung cấp các phương thức cho phép đọc dữ liệu từ các
# nguồn như csv, excel, json, hdf5, html... đưa vào DataFrame.
#
# * Đọc dữ liệu từ file csv: df=pd.read_csv('FoodPrice_in_Turkey.csv')
#
# * Đọc dữ liệu từ file excel: df=pd.read_excel('house_price_đống đa.xlsx')
#
# * Đọc dữ liệu từ file Json: df = pd.read_json('FoodPrice.json')
#
# * Đọc dữ liệu từ file hdf5: df=pd.read_hdf('FoodPrice.h5', 'table')
#
# * Đọc dữ liệu từ file html: df=pd.read_html('demo_FoodPrice.html')
#
# * Đọc dữ liệu từ liên kết url: url = 'https://en.wikipedia.org/wiki/List_of_sovereign_states_and_dependent_territories_in_North_America':
# df = pd.read_html(url)

# %%
df = pd.read_csv('FoodPrice_in_Turkey.csv')
df.head()
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price
# 0  4.4920
# 1  4.5786
# 2  4.7865
# 3  5.1337
# 4  5.5099

# %%
# Trước khi tiền xử lý dữ liệu

# Xem dữ liệu trông như thế nào

# In 5 dòng đầu, 5 dòng cuối, 5 dòng ngẫu nhiên

# Tổng quát

# Tổng quát về cấu trúc dữ liệu
  # Bao nhiêu dòng, bao nhiêu cột -> df.shape()
  # Tên cột -> df.columns
  # Kiểu dữ liệu ở từng cột (numeric, ngày tháng...) -> df.info()

# %%
# Xem 5 dòng đầu
df.head()
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price
# 0  4.4920
# 1  4.5786
# 2  4.7865
# 3  5.1337
# 4  5.5099

# %%
# Xem 5 dòng cuối
df.tail()
# Out:
#       Place  ProductId              ProductName  UmId UmName  Month  Year  \
# 7376  Izmir        502  Cocoa (powder) - Retail     5     KG      8  2019
# 7377  Izmir        502  Cocoa (powder) - Retail     5     KG      9  2019
# 7378  Izmir        502  Cocoa (powder) - Retail     5     KG     10  2019
# 7379  Izmir        502  Cocoa (powder) - Retail     5     KG     11  2019
# 7380  Izmir        502  Cocoa (powder) - Retail     5     KG     12  2019
#
#         Price
# 7376  47.9040
# 7377  49.1176
# 7378  50.8347
# 7379  51.7985
# 7380  51.6071

# %%
# Xem 5 dòng ngẫu nhiên
df.sample(5)
# Out:
#                  Place  ProductId             ProductName  UmId UmName  Month  \
# 1349  National Average        229   Apples (red) - Retail     5     KG      4
# 5539          Istanbul        434      Eggplants - Retail     5     KG      6
# 178   National Average         66  Beans (white) - Retail     5     KG      5
# 6849             Izmir        345         Apples - Retail     5     KG      4
# 3961            Ankara        434      Eggplants - Retail     5     KG     11
#
#       Year   Price
# 1349  2016  2.3800
# 5539  2019  4.0833
# 178   2018  8.0966
# 6849  2018  3.7024
# 3961  2019  2.5881

# %% [markdown]
# ## Ghi dữ liệu DataFrame vào các file khác nhau

# %% [markdown]
# Dữ liệu từ DataFrame df sau khi được phân tích xử lý có thể được lưu vào các file với các định dạng khác nhau.
#
# * Ghi dữ liệu từ DataFrame vào file csv: df.to_csv('demo_FoodPrice.csv')
#
# * Ghi dữ liệu từ DataFrame vào file excel: df.to_excel('demo_FoodPrice.xlsx')
#
# * Ghi dữ liệu từ DataFrame vào file Json dưới dạng cột: df.to_json('demo_FoodPrice.json',orient='columns')
#
# * Ghi dữ liệu từ DataFrame vào file hdf5 dưới dạng bảng: df.to_hdf('demo_FoodPrice.h5', 'table')
#
# * Ghi dữ liệu từ DataFrame vào file html: df.to_html('demo_FoodPrice.html')

# %%
df.to_csv('demo_FoodPrice.csv')

# %% [markdown]
# ## Mô tả cấu trúc dữ liệu

# %% [markdown]
# ### 1. Xác định số hàng và cột của DataFrame

# %%
df.shape
# Out:
# (7381, 8)

# %%
print("Số dòng dữ liệu: ", df.shape[0])
print("Số cột dữ liệu: ", df.shape[1])
# Out:
# Số dòng dữ liệu:  7381
# Số cột dữ liệu:  8

# %% [markdown]
# ### 2. Kiểm tra tên của các cột thuộc tính

# %%
df.columns
# Out:
# Index(['Place', 'ProductId', 'ProductName', 'UmId', 'UmName', 'Month', 'Year',
#        'Price'],
#       dtype='object')

# %% [markdown]
# ### 3. Kiểm tra kiểu dữ liệu của các cột thuộc tính

# %%
df.info
# Out:
# <bound method DataFrame.info of                  Place  ProductId              ProductName  UmId UmName  \
# 0     National Average         52            Rice - Retail     5     KG
# 1     National Average         52            Rice - Retail     5     KG
# 2     National Average         52            Rice - Retail     5     KG
# 3     National Average         52            Rice - Retail     5     KG
# 4     National Average         52            Rice - Retail     5     KG
# ...                ...        ...                      ...   ...    ...
# 7376             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7377             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7378             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7379             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7380             Izmir        502  Cocoa (powder) - Retail     5     KG
#
#       Month  Year    Price
# 0         5  2013   4.4920
# ...

# %%
# Dùng dtypes (data types)
df.dtypes
# Out:
# Place           object
# ProductId        int64
# ProductName     object
# UmId             int64
# UmName          object
# Month            int64
# Year             int64
# Price          float64
# dtype: object

# %%
# Dùng info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7381 entries, 0 to 7380
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Place        7381 non-null   object
#  1   ProductId    7381 non-null   int64
#  2   ProductName  7381 non-null   object
#  3   UmId         7381 non-null   int64
#  4   UmName       7381 non-null   object
#  5   Month        7381 non-null   int64
#  6   Year         7381 non-null   int64
#  7   Price        7381 non-null   float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 461.4+ KB

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Thành phần trong Pandas
# DataFrame
# Series
# Index: địa chỉ -> truy cập dữ liệu

# Truy cập trực tiếp: 'Hưng', 'Khâm Thiên Hà Nội' -> .loc
# Truy cập theo đếm số: bạn số 2 -> i (integer)loc -> .iloc

# .loc[hàng, cột]

# %% [markdown]
# ## Truy cập dữ liệu

# %% [markdown]
# Trong Pandas, có 2 phương thức chính để truy cập dữ liệu:
#
# * iloc giúp truy cập hàng và cột thông qua các chỉ số của chúng. Tham số truyền vào là một số nguyên hoặc một tập các số nguyên.
#
# * loc giúp truy cập tới hàng và cột thông qua các chỉ số của hàng; tên hoặc biểu thức điều kiện của cột. Cú pháp: .loc[, ]

# %% [markdown]
# ### iloc

# %%
# 0, 1, 2, 3, ...

# %%
# Truy cập dòng có chỉ số 3 của dữ liệu
tg = df.iloc[3]
tg
# Out:
# Place          National Average
# ProductId                    52
# ProductName       Rice - Retail
# UmId                          5
# UmName                       KG
# Month                        12
# Year                       2013
# Price                    5.1337
# Name: 3, dtype: object

# %%
# Truy cập các dòng có chỉ số liên tục từ 3 tới 8 của dữ liệu
tg = df.iloc[3:8] #từ 3 tới 8-1
tg
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
# 5  National Average         52  Rice - Retail     5     KG      2  2014
# 6  National Average         52  Rice - Retail     5     KG      3  2014
# 7  National Average         52  Rice - Retail     5     KG      5  2014
#
#     Price
# 3  5.1337
# 4  5.5099
# 5  5.8146
# 6  6.0014
# 7  6.3202

# %%
# Truy cập các dòng rời rạc của dữ liệu
tg = df.iloc[[3,5,7]]
tg
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 5  National Average         52  Rice - Retail     5     KG      2  2014
# 7  National Average         52  Rice - Retail     5     KG      5  2014
#
#     Price
# 3  5.1337
# 5  5.8146
# 7  6.3202

# %%
#df.iloc[hàng, cột]
#df.iloc[:, cột số mấy]

# %%
# Truy cập cột thứ 4 của dữ liệu
# : được sử dụng để đại diện cho tất cả các dòng.
tg = df.iloc[:,4]
tg
# hàng 3 cột 4
df.iloc[3,4]
# Out:
# 'KG'

# %%
# Truy cập các cột liên tục từ cột 3 tới cột 8 của dữ liệu
tg = df.iloc[:,3:8]
tg
# Out:
#       UmId UmName  Month  Year    Price
# 0        5     KG      5  2013   4.4920
# 1        5     KG      6  2013   4.5786
# 2        5     KG     11  2013   4.7865
# 3        5     KG     12  2013   5.1337
# 4        5     KG      1  2014   5.5099
# ...    ...    ...    ...   ...      ...
# 7376     5     KG      8  2019  47.9040
# 7377     5     KG      9  2019  49.1176
# 7378     5     KG     10  2019  50.8347
# 7379     5     KG     11  2019  51.7985
# 7380     5     KG     12  2019  51.6071
#
# [7381 rows x 5 columns]

# %%
# Truy cập tới phần tử tại dòng 3 cột 7 của dữ liệu
tg = df.iloc[3,7]
tg
# Out:
# 5.1337

# %%
# Truy cập tới các phần tử từ dòng 3 đến dòng 4, cột 5 đến cột 6 của dữ liệu
tg = df.iloc[3:5,5:7]
tg
# Out:
#    Month  Year
# 3     12  2013
# 4      1  2014

# %%
# hàng trước cột sau
# không quan tâm (lấy hết) :
# chuỗi: 3:6

# lấy giá trị ở cột 3 đến 6  (in đến cột 5)
# lấy giá trị ở hàng 30 cột 5
# lấy giá trị ở hàng 20 đến 30 (in đến hàng 29), cột 2 đến 5 (in đến cột 4)

# %%
df.iloc[:, 3:6]
# Out:
#       UmId UmName  Month
# 0        5     KG      5
# 1        5     KG      6
# 2        5     KG     11
# 3        5     KG     12
# 4        5     KG      1
# ...    ...    ...    ...
# 7376     5     KG      8
# 7377     5     KG      9
# 7378     5     KG     10
# 7379     5     KG     11
# 7380     5     KG     12
#
# [7381 rows x 3 columns]

# %%
df.iloc[30,5]
# Out:
# 4

# %%
df.iloc[20:30:2, 2:5:2]
# Out:
#       ProductName UmName
# 20  Rice - Retail     KG
# 22  Rice - Retail     KG
# 24  Rice - Retail     KG
# 26  Rice - Retail     KG
# 28  Rice - Retail     KG

# %%
# Tổng kết

# Pandas là gì -> thưu viện trong Python
# Gồm: DataFrame (bảng 2 chiều có hàng có cột), Series (một cột, 1 chiều)

# Tạo Bảng thủ công
# Tạo series thủ công

# Xử lý DataFrame
# 1. Xem bảng trông như thế nào: df.head(), df.tail(), df.sample(n)
# 2. Xem tổng quát về bảng: cấu trúc
  # bao nhiêu hàng, bao nhiêu cột: df.shape
  # tên cột: df.columns
  # kiểu dữ liệu từng cột: df.dtypes hoặc df.info()
# 3. Truy cập dữ liệu
  # Truy cập qua đếm số - .iloc (integer location)
    # syntax chung
    # df.iloc[hàng, cột]

    # gọi hàng
    # một hàng cụ thể: df.iloc[2]
    # một chuỗi hàng: df.iloc[2:5]

    # gọi cột
    # chỉ cột: df.iloc[:, 3]
    # một chuỗi cột: df.iloc[:, 3:8]

    # kết hợp hàng và cột
    # kết hợp: df.iloc[3,8]
    # kết hợp chuỗi: df.iloc[2:9, 3:8]

    # step?

  # Truy cập trực tiếp (gọi index, gọi tên cột) - .loc (location)

# %% [markdown]
# ### loc

# %% [markdown]
# Giống như iloc

# %%
# iloc -> vị trí số mấy.
# dòng số 3: df.iloc[3]
# cột số 3: df.iloc[:,3]

# iloc -> loc: gọi trực tiếp
# cột 'Tuổi' -> df.loc[:, 'Tuổi']
# Dòng -> df.loc['Ngân']

# %%
# Truy cập dòng có chỉ số 3 của dữ liệu
tg = df.loc[3]
tg
# Out:
# Place          National Average
# ProductId                    52
# ProductName       Rice - Retail
# UmId                          5
# UmName                       KG
# Month                        12
# Year                       2013
# Price                    5.1337
# Name: 3, dtype: object

# %%
student_dict = {'Name': ['Ngân', 'Đạt', 'Hưng'], 'Age': [20, 21, 19], 'Marks': [85.10, 77.80, 91.54]}

# create DataFrame from dict
student_df = pd.DataFrame(student_dict)
print(student_df)

# lấy bạn Ngan
print(student_df.loc[0])
# Out:
#    Name  Age  Marks
# 0  Ngân   20  85.10
# 1   Đạt   21  77.80
# 2  Hưng   19  91.54
# Name     Ngân
# Age        20
# Marks    85.1
# Name: 0, dtype: object

# %%
# tạo bảng student_df1, trong đó:
student_df1 = student_df.set_index('Name')
print(student_df1)

# lấy bạn Ngan
print(student_df1.loc['Ngân'])
# Out:
#       Age  Marks
# Name
# Ngân   20  85.10
# Đạt    21  77.80
# Hưng   19  91.54
# Age      20.0
# Marks    85.1
# Name: Ngân, dtype: float64

# %%
df.head()
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price
# 0  4.4920
# 1  4.5786
# 2  4.7865
# 3  5.1337
# 4  5.5099

# %%
# Truy cập cột thứ 4 của dữ liệu
tg = df.loc[:,'UmName']
tg
# Out:
# 0       KG
# 1       KG
# 2       KG
# 3       KG
# 4       KG
#         ..
# 7376    KG
# 7377    KG
# 7378    KG
# 7379    KG
# 7380    KG
# Name: UmName, Length: 7381, dtype: object

# %%
df.loc[:,'UmId']
# Out:
# 0       5
# 1       5
# 2       5
# 3       5
# 4       5
#        ..
# 7376    5
# 7377    5
# 7378    5
# 7379    5
# 7380    5
# Name: UmId, Length: 7381, dtype: int64

# %%
# Truy cập cột thứ 4,5 của dữ liệu
tg = df.loc[:,['UmName','Month']]
tg
# Out:
#      UmName  Month
# 0        KG      5
# 1        KG      6
# 2        KG     11
# 3        KG     12
# 4        KG      1
# ...     ...    ...
# 7376     KG      8
# 7377     KG      9
# 7378     KG     10
# 7379     KG     11
# 7380     KG     12
#
# [7381 rows x 2 columns]

# %%
df.loc[:,['Month','Year']]
# Out:
#       Month  Year
# 0         5  2013
# 1         6  2013
# 2        11  2013
# 3        12  2013
# 4         1  2014
# ...     ...   ...
# 7376      8  2019
# 7377      9  2019
# 7378     10  2019
# 7379     11  2019
# 7380     12  2019
#
# [7381 rows x 2 columns]

# %%
# Truy cập tới phần tử tại dòng tên 3 cột tên Price của dữ liệu
tg = df.loc[3,'Price']
tg
# Out:
# 5.1337

# %%
df.loc[4, 'Month']
# Out:
# 1

# %%
# Truy cập tới phần tử có Year >=2019
tg = df.loc[df.Year >= 2019]
tg
# Out:
#                  Place  ProductId              ProductName  UmId UmName  \
# 54    National Average         52            Rice - Retail     5     KG
# 55    National Average         52            Rice - Retail     5     KG
# 56    National Average         52            Rice - Retail     5     KG
# 57    National Average         52            Rice - Retail     5     KG
# 58    National Average         52            Rice - Retail     5     KG
# ...                ...        ...                      ...   ...    ...
# 7376             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7377             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7378             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7379             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7380             Izmir        502  Cocoa (powder) - Retail     5     KG
#
#       Month  Year    Price
# 54        1  2019   8.4275
# 55        2  2019   8.7656
# ...

# %%
df.loc[df.Month>=5]
# Out:
#                  Place  ProductId              ProductName  UmId UmName  \
# 0     National Average         52            Rice - Retail     5     KG
# 1     National Average         52            Rice - Retail     5     KG
# 2     National Average         52            Rice - Retail     5     KG
# 3     National Average         52            Rice - Retail     5     KG
# 7     National Average         52            Rice - Retail     5     KG
# ...                ...        ...                      ...   ...    ...
# 7376             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7377             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7378             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7379             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7380             Izmir        502  Cocoa (powder) - Retail     5     KG
#
#       Month  Year    Price
# 0         5  2013   4.4920
# 1         6  2013   4.5786
# ...

# %%
df.loc[3:10, 'ProductId':'Price']
# Out:
#     ProductId    ProductName  UmId UmName  Month  Year   Price
# 3          52  Rice - Retail     5     KG     12  2013  5.1337
# 4          52  Rice - Retail     5     KG      1  2014  5.5099
# 5          52  Rice - Retail     5     KG      2  2014  5.8146
# 6          52  Rice - Retail     5     KG      3  2014  6.0014
# 7          52  Rice - Retail     5     KG      5  2014  6.3202
# 8          52  Rice - Retail     5     KG      6  2014  6.6019
# 9          52  Rice - Retail     5     KG      7  2014  6.6503
# 10         52  Rice - Retail     5     KG      8  2014  6.6806

# %%
df.loc[0:10, 'UmName':'Price']
# Out:
#    UmName  Month  Year   Price
# 0      KG      5  2013  4.4920
# 1      KG      6  2013  4.5786
# 2      KG     11  2013  4.7865
# 3      KG     12  2013  5.1337
# 4      KG      1  2014  5.5099
# 5      KG      2  2014  5.8146
# 6      KG      3  2014  6.0014
# 7      KG      5  2014  6.3202
# 8      KG      6  2014  6.6019
# 9      KG      7  2014  6.6503
# 10     KG      8  2014  6.6806

# %%
# .loc -> gọi tên
# .iloc -> đếm

# .loc
# dòng trước cột sau

# Dòng
# Truy cập tới 1 dòng của dữ liệu: df.loc[tên địa chỉ dòng]
# Truy cập tới nhiều dòng liên tiếp của dữ liệu: df.loc[tên địa chỉ dòng a : tên địa chỉ dòng b]

# Cột
# Truy cập tới 1 cột của dữ liệu: df.loc[:, tên cột]
# Truy cập tới nhiều cột rời rạc của dữ liệu: df.loc[:, [tên cột A, tên cột B, tên cột C]]
# Truy cập tới nhiều cột liên tiếp của dữ liệu: df.loc[:, tên cột A : tên cột E]

# Dòng và Cột
# Truy cập vào 1 giá trị có tên dòng và tên cột cụ thể: df.loc[tên dòng, tên cột]
# Truy cập tới nhiều dòng rời rạc và nhiều cột rời rạc của dữ liệu:
# df.loc[[tên dòng a, tên dòng b, tên dòng c], [tên cột x, tên cột y, tên cột z]]
# Truy cập tới nhiều dòng liên tiếp và nhiều cột liên tiếp của dữ liệu:
# df.loc[tên dòng a : tên dòng d, tên cột x : tên cột z]

# %%
# Xem dữ liệu
# Xem cấu trúc
  # Xem trông như nào -> df.head(), df.tail(), df.sample(n)
  # Xem có bao nhiêu dòng, bao nhiêu cột -> df.shape -> xoá
  # Xem tên cột -> df.columns -> đổi tên cột
  # Xem định dạng từng cột -> df.info() -> đổi định dạng cột

# %%
# Đổi tên cột
# Thêm
  # Thêm cột
  # Thêm dòng
# Xoá
  # Xoá cột
  # Xoá dòng

# %% [markdown]
# # Chỉnh sửa dữ liệu

# %% [markdown]
# ## Chỉnh sửa cấu trúc dữ liệu

# %% [markdown]
# ### Đổi tên cột thuộc tính

# %%
# rename(): đổi tên
# gọi dữ liệu: df
# áp hàm đổi tên vào dữ liệu: df.rename()
# chỉ định đổi tên cột nào: Place, ProductName
# chỉ định thay tên thành gì: Địa điểm, Tên SP
# chỉ định -> columns={'Place':'Địa điểm', 'ProductName':'Tên SP'}

df = df.rename(columns={'Place':'Địa điểm', 'ProductName':'Tên SP'})
df.rename(columns={'Place':'Địa điểm', 'ProductName':'Tên SP'}, inplace=True)

# %%
df.rename(columns={'Place':'Địa điểm','ProductName':'Tên SP'},inplace=True)
df.head()
# Out:
#            Địa điểm  ProductId         Tên SP  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price
# 0  4.4920
# 1  4.5786
# 2  4.7865
# 3  5.1337
# 4  5.5099

# %% [markdown]
# ### Thêm cột mới trong DataFrame

# %%
# gọi bảng mình muốn sửa: df
# thêm cột: df['tên cột mới'] = giá trị cột mới

# %%
# Thêm một cột mới với tất cả các giá trị rỗng NaN
df['new_column'] = 'NaN'
df.head()
# Out:
#            Địa điểm  ProductId         Tên SP  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price new_column
# 0  4.4920        NaN
# 1  4.5786        NaN
# 2  4.7865        NaN
# 3  5.1337        NaN
# 4  5.5099        NaN

# %%
# Thêm cột giảm giá 10% cho tất cả các bản ghi
# Cách 1: Gán tên cột dưới dạng một chuỗi và thêm giá trị cho cột đó
df['Giảm giá']= pd.Series('10%', index=df.index)
df.head()
# Out:
#            Địa điểm  ProductId         Tên SP  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price new_column Giảm giá
# 0  4.4920        NaN      10%
# 1  4.5786        NaN      10%
# 2  4.7865        NaN      10%
# 3  5.1337        NaN      10%
# 4  5.5099        NaN      10%

# %%
# bảng mình muốn xử lý: df
# áp hàm vào bảng: .insert -> df.insert()
# Thứ 1: chỉ định vị trí mình muốn chèn cột mới: 10
# Thứ 2: chỉ định tên cột mới: 'Giảm giá 2'
# Thứ 3: Chỉ định giá trị của cột mới: '12%

# df.insert(10, 'Giảm giá 2', pd.Series('12%', index=df.index))

# %%
# Thêm cột giảm giá 12% cho tất cả các bản ghi
# Cách 2: Sử dụng phương thức insert() gồm 3 đối số
# - đối số đầu tiên là chỉ mục (vị trí) muốn chèn cột mới (chỉ mục là 10--> cột mới được thêm vào vị trí 11 của DataFrame)
# - đối số thứ hai là tên của cột mới muốn chèn
# - đối số thứ ba giá trị của cột
df.insert(10,'Giảm giá 2', pd.Series('12%', index=df.index))
df.head()
# Out:
#            Địa điểm  ProductId         Tên SP  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price new_column Giảm giá Giảm giá 2
# 0  4.4920        NaN      10%        12%
# 1  4.5786        NaN      10%        12%
# 2  4.7865        NaN      10%        12%
# 3  5.1337        NaN      10%        12%
# 4  5.5099        NaN      10%        12%

# %% [markdown]
# ### Thêm dòng mới vào DataFrame

# %%
# df['cột mới'] = giá trị

# thêm dòng
# dữ liệu mình muốn xử lý: df
# hàm mình muốn áp vào dữ liệu: .append()
# chỉ định giá trị cho dòng mới
# Địa điểm: 'NA'
# ProductId: 'RR'
# Tên SP: 'Rice'
# UmId: 10
# UmName: 'KG'
# Month: 6
# Year: 2021
# Price: 84.3785
# Giảm giá: 10%
# Giảm giá 2: 12%
# không quan tâm index

# %%
# Sử dụng phương thức append() thêm một dòng vào cuối DataFrame
df=df.append({'Địa điểm':'NA','ProductId':'RR','Tên SP':'Rice','UmId':10,'UmName':'KG','Month':6,'Year':2021,'Price':84.3785,'Giảm giá':'10%','Giảm giá 2':'12%'},ignore_index=True)
df.tail()  # Hiển thị 5 bản ghi cuối
# Out:
# <ipython-input-99-fd9ea64b6545>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append({'Địa điểm':'NA','ProductId':'RR','Tên SP':'Rice','UmId':10,'UmName':'KG','Month':6,'Year':2021,'Price':84.3785,'Giảm giá':'10%','Giảm giá 2':'12%'},ignore_index=True)
#      Địa điểm ProductId                   Tên SP  UmId UmName  Month  Year  \
# 7377    Izmir       502  Cocoa (powder) - Retail     5     KG      9  2019
# 7378    Izmir       502  Cocoa (powder) - Retail     5     KG     10  2019
# 7379    Izmir       502  Cocoa (powder) - Retail     5     KG     11  2019
# 7380    Izmir       502  Cocoa (powder) - Retail     5     KG     12  2019
# 7381       NA        RR                     Rice    10     KG      6  2021
#
#         Price new_column Giảm giá Giảm giá 2
# 7377  49.1176        NaN      10%        12%
# 7378  50.8347        NaN      10%        12%
# ...

# %% [markdown]
# ### Xoá một cột trong DataFrame

# %%
# Xóa một cột sử dụng hàm del
del df['new_column']
df.head()
# Out:
#            Địa điểm ProductId         Tên SP  UmId UmName  Month  Year  \
# 0  National Average        52  Rice - Retail     5     KG      5  2013
# 1  National Average        52  Rice - Retail     5     KG      6  2013
# 2  National Average        52  Rice - Retail     5     KG     11  2013
# 3  National Average        52  Rice - Retail     5     KG     12  2013
# 4  National Average        52  Rice - Retail     5     KG      1  2014
#
#     Price Giảm giá Giảm giá 2
# 0  4.4920      10%        12%
# 1  4.5786      10%        12%
# 2  4.7865      10%        12%
# 3  5.1337      10%        12%
# 4  5.5099      10%        12%

# %%
# Xóa một cột sử dụng phương thức pop()
# Phương thức pop trả về cột đã xóa
df.pop('Giảm giá 2')
# Out:
# 0       12%
# 1       12%
# 2       12%
# 3       12%
# 4       12%
#        ...
# 7377    12%
# 7378    12%
# 7379    12%
# 7380    12%
# 7381    12%
# Name: Giảm giá 2, Length: 7382, dtype: object

# %%
# dữ liệu mình muốn xử lý: df
# bỏ: .drop()
# bỏ cái gì? -> 'Giảm giá'
# bỏ cột hay bỏ dòng ->
  # bỏ cột -> axis = 1
  # bỏ dòng -> axis = 0

# df.drop(['Giảm giá', 'Giảm giá 2'], axis=1, inplace=True)

# %%
# Xóa một cột sử dụng phương thức drop()
# Cú pháp: df.drop('column_name', axis=1, inplace=True)
# Trong đó axis = 1 là xóa cột; inplace = True xóa trục tiếp trên dữ liệu gốc mà không phải tạo bản sao
df.drop('Giảm giá', axis=1, inplace=True)
df
# Out:
#               Địa điểm ProductId                   Tên SP  UmId UmName  Month  \
# 0     National Average        52            Rice - Retail     5     KG      5
# 1     National Average        52            Rice - Retail     5     KG      6
# 2     National Average        52            Rice - Retail     5     KG     11
# 3     National Average        52            Rice - Retail     5     KG     12
# 4     National Average        52            Rice - Retail     5     KG      1
# ...                ...       ...                      ...   ...    ...    ...
# 7377             Izmir       502  Cocoa (powder) - Retail     5     KG      9
# 7378             Izmir       502  Cocoa (powder) - Retail     5     KG     10
# 7379             Izmir       502  Cocoa (powder) - Retail     5     KG     11
# 7380             Izmir       502  Cocoa (powder) - Retail     5     KG     12
# 7381                NA        RR                     Rice    10     KG      6
#
#       Year    Price
# ...

# %%
# Xóa nhiều cột sử dụng phương thức drop()
df.drop(['Month','Year'], axis=1, inplace=True)
df
# Out:
#               Địa điểm ProductId                   Tên SP  UmId UmName  \
# 0     National Average        52            Rice - Retail     5     KG
# 1     National Average        52            Rice - Retail     5     KG
# 2     National Average        52            Rice - Retail     5     KG
# 3     National Average        52            Rice - Retail     5     KG
# 4     National Average        52            Rice - Retail     5     KG
# ...                ...       ...                      ...   ...    ...
# 7377             Izmir       502  Cocoa (powder) - Retail     5     KG
# 7378             Izmir       502  Cocoa (powder) - Retail     5     KG
# 7379             Izmir       502  Cocoa (powder) - Retail     5     KG
# 7380             Izmir       502  Cocoa (powder) - Retail     5     KG
# 7381                NA        RR                     Rice    10     KG
#
#         Price
# 0      4.4920
# 1      4.5786
# 2      4.7865
# 3      5.1337
# 4      5.5099
# ...       ...
# ...

# %% [markdown]
# ### Xoá các dòng trong DataFrame

# %%
# Cú pháp: df.drop(Chỉ số dòng cần xóa, axis=0, inplace=True)
# axis = 0 là giá trị mặc định có thể viết tường minh hoặc không
# Xóa dòng có chỉ số 1 (dòng thứ 2) sử dụng phương thức drop()

df.drop(1, axis = 0, inplace=True)
df
# Out:
#               Địa điểm ProductId                   Tên SP  UmId UmName  \
# 0     National Average        52            Rice - Retail     5     KG
# 2     National Average        52            Rice - Retail     5     KG
# 3     National Average        52            Rice - Retail     5     KG
# 4     National Average        52            Rice - Retail     5     KG
# 5     National Average        52            Rice - Retail     5     KG
# ...                ...       ...                      ...   ...    ...
# 7377             Izmir       502  Cocoa (powder) - Retail     5     KG
# 7378             Izmir       502  Cocoa (powder) - Retail     5     KG
# 7379             Izmir       502  Cocoa (powder) - Retail     5     KG
# 7380             Izmir       502  Cocoa (powder) - Retail     5     KG
# 7381                NA        RR                     Rice    10     KG
#
#         Price
# 0      4.4920
# 2      4.7865
# 3      5.1337
# 4      5.5099
# 5      5.8146
# ...       ...
# ...

# %%
# Xóa các dòng có chỉ số 7377 và 7379 sử dụng phương thức drop()
df.drop([7377,7379], inplace=True)
df
# Out:
#               Địa điểm ProductId                   Tên SP  UmId UmName  \
# 0     National Average        52            Rice - Retail     5     KG
# 2     National Average        52            Rice - Retail     5     KG
# 3     National Average        52            Rice - Retail     5     KG
# 4     National Average        52            Rice - Retail     5     KG
# 5     National Average        52            Rice - Retail     5     KG
# ...                ...       ...                      ...   ...    ...
# 7375             Izmir       502  Cocoa (powder) - Retail     5     KG
# 7376             Izmir       502  Cocoa (powder) - Retail     5     KG
# 7378             Izmir       502  Cocoa (powder) - Retail     5     KG
# 7380             Izmir       502  Cocoa (powder) - Retail     5     KG
# 7381                NA        RR                     Rice    10     KG
#
#         Price
# 0      4.4920
# 2      4.7865
# 3      5.1337
# 4      5.5099
# 5      5.8146
# ...       ...
# ...

# %% [markdown]
# ## Thay thế các giá trị trong DataFrame

# %%
# replace
# dữ liệu muốn xử lý: df
# hàm để áp vào dữ liệu: replace
# trong hàm, gọi gì
# thứ 1, giá trị muốn thay: 5
# thứ 2, gía trị mới để thay vào: 10
# inplace=True

# %%
# Thay số 5 bằng số 10 trong toàn bộ dữ liệu
df.replace(5,10,inplace = True)
df.head()
# Out:
#            Địa điểm ProductId         Tên SP  UmId UmName   Price
# 0  National Average        52  Rice - Retail    10     KG  4.4920
# 2  National Average        52  Rice - Retail    10     KG  4.7865
# 3  National Average        52  Rice - Retail    10     KG  5.1337
# 4  National Average        52  Rice - Retail    10     KG  5.5099
# 5  National Average        52  Rice - Retail    10     KG  5.8146

# %%
# Thay mã sản phẩm từ giá trị 52 thành RR trong toàn bộ dữ liệu
# RR là chuỗi ký tự nên được để trong cặp dấu nháy đơn
df.replace(52,'RR',inplace = True)
df.head()
# Out:
#            Địa điểm ProductId         Tên SP  UmId UmName   Price
# 0  National Average        RR  Rice - Retail    10     KG  4.4920
# 2  National Average        RR  Rice - Retail    10     KG  4.7865
# 3  National Average        RR  Rice - Retail    10     KG  5.1337
# 4  National Average        RR  Rice - Retail    10     KG  5.5099
# 5  National Average        RR  Rice - Retail    10     KG  5.8146

# %%
df['UmName'].replace('KG','kg',inplace = True)
df.head()
# Out:
#            Địa điểm ProductId         Tên SP  UmId UmName   Price
# 0  National Average        RR  Rice - Retail    10     kg  4.4920
# 2  National Average        RR  Rice - Retail    10     kg  4.7865
# 3  National Average        RR  Rice - Retail    10     kg  5.1337
# 4  National Average        RR  Rice - Retail    10     kg  5.5099
# 5  National Average        RR  Rice - Retail    10     kg  5.8146

# %%
# .loc, .iloc

# Chỉnh sửa dữ liệu
# Chỉnh sửa cấu trúc
  # Đổi tên cột: .rename(columns={'a': 'c', ...}, inplace=True)
  # Thêm
    # Thêm cột: df['tên cột mới'] = giá trị cột mới
    # Thêm dòng: .append(giá trị mới cho dòng)
  # Xoá
    # Xoá cột: .drop(tên cột muốn xoá, axis=1, inplace=True)
    # Xoá dòng: .drop(địa chỉ dòng muốn xoá, axis=0, inplace=True)
# Chỉnh sửa nội dung
    # .replace(nội dung muốn sửa, nội dụng mới để thay, inplace=True)
