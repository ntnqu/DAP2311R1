# %% [markdown]
# # Set Up

# %%
import pandas as pd

# %%
df=pd.read_csv('shopeep_koreantop_clothing_shop_data.csv')

# %%
# Thao tác xử lý DataFrame

# 1 Bảng

  # Đọc bảng: pd.read_csv()
  # Kiểm tra bảng:
    # Xem bảng trông như thế nào: df.head(), df.tail(), df.sample(n)
    # Xem tổng quát về bảng:
      # Cấu trúc
        # Bao nhiêu hàng, bao nhiêu cột -> df.shape
        # Tên cột: df.columns
        # Kiểu dữ liệu từng cột: df.info()
      # Nội dung -> Giá trị thống kê
  # Xử lý bảng
    # Truy cập dữ liệu
      # .loc()
      # .iloc()
    # BỔ SUNG: LỌC DỮ LIỆU
    # Chỉnh sửa dữ liệu
      # Chỉnh sửa cấu trúc
        # Đổi tên côt: .rename()
        # Thêm cột mới: df['cột mới'] = giá trị cột mới
        # Thêm dòng mới: .append()
        # Xoá cột: .drop(cột muốn xoá, axis = 1, inplace=True)
        # Xoá dòng: .drop(dòng muốn xoá, axis = 0, inplace=True)
      # Chỉnh sủa nội dung: .replace(giá trị muốn thay, giá trị mới, inplace=True)
    # Tổng hợp dữ liệu: pivot_table()
  # Xuất bảng: df.to_csv('filename.csv')

# 2 Bảng trở lên -> Hợp nhất dữ liệu từ nhiều nguồn
  # Hợp nhất cột
  # Hợp nhất dòng

# %% [markdown]
# # Lọc dữ liệu

# %% [markdown]
# ## Lọc dữ liệu hàng, cột theo tên, theo chỉ số

# %% [markdown]
# ### Lấy một cột theo tên cột

# %%
# Cách 1: dùng phương thức filter
df1 = df.filter(['shop_location'])
df1
# Out:
#                   shop_location
# 0                           NaN
# 1      San Nicolas,Metro Manila
# 2       Pasay City,Metro Manila
# 3          Binondo,Metro Manila
# 4    Caloocan City,Metro Manila
# ..                          ...
# 741          Legazpi City,Albay
# 742                         NaN
# 743                         NaN
# 744        Binondo,Metro Manila
# 745     Pasay City,Metro Manila
#
# [746 rows x 1 columns]

# %%
# Cách 2: truyền trực tiếp tên cột
df1 = df[['shop_location']]
df1
# Out:
#                   shop_location
# 0                           NaN
# 1      San Nicolas,Metro Manila
# 2       Pasay City,Metro Manila
# 3          Binondo,Metro Manila
# 4    Caloocan City,Metro Manila
# ..                          ...
# 741          Legazpi City,Albay
# 742                         NaN
# 743                         NaN
# 744        Binondo,Metro Manila
# 745     Pasay City,Metro Manila
#
# [746 rows x 1 columns]

# %% [markdown]
# ### Lấy nhiều cột theo tên cột

# %%
# Cách 1: dùng phương thức filter
df2 = df.filter(['join_month', 'join_day', 'join_year'])
df2
# Out:
#     join_month  join_day  join_year
# 0        April        27       2020
# 1    September        25       2020
# 2    September        27       2016
# 3        April        30       2017
# 4      October        18       2016
# ..         ...       ...        ...
# 741        May        22       2021
# 742      March         3       2021
# 743   December        20       2020
# 744     August         2       2017
# 745       June        17       2017
#
# [746 rows x 3 columns]

# %%
# Cách 2: truyền trực tiếp tên cột
df2 = df[['join_month', 'join_day', 'join_year']]
df2
# Out:
#     join_month  join_day  join_year
# 0        April        27       2020
# 1    September        25       2020
# 2    September        27       2016
# 3        April        30       2017
# 4      October        18       2016
# ..         ...       ...        ...
# 741        May        22       2021
# 742      March         3       2021
# 743   December        20       2020
# 744     August         2       2017
# 745       June        17       2017
#
# [746 rows x 3 columns]

# %% [markdown]
# ### Lấy thông tin các bản ghi theo chỉ số

# %%
# Cách 1: dùng phương thức filter, cho phép lấy các bản ghi rời rạc, các chỉ số được ngăn cách nhau bởi dấu phẩy.
df3 = df2.filter([0,1,2,3,4,5,6,7], axis=0)
df3
# Out:
#   join_month  join_day  join_year
# 0      April        27       2020
# 1  September        25       2020
# 2  September        27       2016
# 3      April        30       2017
# 4    October        18       2016
# 5      April        26       2021
# 6  September        17       2020
# 7   February        12       2019

# %%
# Cách 2: truyền chỉ số trực tiếp, cho phép lấy một hoặc nhiều bản ghi liên tiếp
df3 = df2[0:8]
df3
# Out:
#   join_month  join_day  join_year
# 0      April        27       2020
# 1  September        25       2020
# 2  September        27       2016
# 3      April        30       2017
# 4    October        18       2016
# 5      April        26       2021
# 6  September        17       2020
# 7   February        12       2019

# %% [markdown]
# ### Lấy thông tin kết hợp theo hàng và cột

# %%
# Cách 1: dùng phương thức filter.
df4 = df.filter(['pk_shop','rating_bad','rating_good'])[:8]
df4
# Out:
#              pk_shop  rating_bad  rating_good
# 0  20210613254711738         181        17510
# 1  20210613314198143          78         2656
# 2   2021061310377223        4647      1071829
# 3   2021061321407329          44        18959
# 4   2021061311187885         680        39252
# 5  20210613430999411           0            2
# 6  20210613310915998          87        16460
# 7  20210613126018720         354        22350

# %%
# Cách 2: truyền chỉ số
df4 = df[['pk_shop','rating_bad','rating_good']][:8]
df4
# Out:
#              pk_shop  rating_bad  rating_good
# 0  20210613254711738         181        17510
# 1  20210613314198143          78         2656
# 2   2021061310377223        4647      1071829
# 3   2021061321407329          44        18959
# 4   2021061311187885         680        39252
# 5  20210613430999411           0            2
# 6  20210613310915998          87        16460
# 7  20210613126018720         354        22350

# %% [markdown]
# ## Lọc bản ghi theo điều kiện

# %% [markdown]
# ### Lọc các bản ghi theo điều kiện đơn

# %%
# Trong lọc có điều kiện, ta có thể sử dụng các phép toán so sánh gồm ==, <, <=, >, >=, !=
# Ví dụ: Tìm các bản ghi có join_month là ‘April’
df[df['join_month']=='April']
# Out:
#                pk_shop date_collected     shopid                     name  \
# 0    20210613254711738     2021-06-13  254711738             hello.may.ph
# 3     2021061321407329     2021-06-13   21407329              patriciacai
# 5    20210613430999411     2021-06-13  430999411            Bellamy House
# 13    2021061364909141     2021-06-13   64909141  ikon Bra Dress Crop top
# 17    2021061320477406     2021-06-13   20477406         PinSan UnderWear
# ..                 ...            ...        ...                      ...
# 724  20210706419928844     2021-07-06  419928844       Only For You，today
# 735  20210706141606030     2021-07-06  141606030        🌿 Peppermint Shop
# 737  20210706416886409     2021-07-06  416886409                 vaapo.ph
# 738  20210706419954100     2021-07-06  419954100    Fall in love with you
# 739   2021070664360491     2021-07-06   64360491                Yzkzks.ph
#
#     join_month  join_day  join_year  item_count  follower_count response_time  \
# 0        April        27       2020         446           17487      10:13:55
# 3        April        30       2017         165           18787      09:10:38
# 5        April        26       2021         115              41      12:33:58
# 13       April        13       2018        3630          195475      10:43:46
# 17       April        17       2017         215          517911      08:05:48
# ..         ...       ...        ...         ...             ...           ...
# 724      April         9       2021         356            1061      09:04:02
# 735      April        22       2019        4206           28039      08:20:51
# 737      April         4       2021         620             228      09:44:25
# 738      April         9       2021         662           12968      09:33:28
# 739      April         9       2018         650           80591      10:41:36
#
#      response_rate            shop_location  rating_bad  rating_good  \
# 0               96                      NaN         181        17510
# 3               94     Binondo,Metro Manila          44        18959
# 5               29                      NaN           0            2
# 13              99                      NaN        1809        99426
# 17              94     Binondo,Metro Manila        7797       608451
# ..             ...                      ...         ...          ...
# 724             98                      NaN          30          426
# 735             67                      NaN          71         6026
# 737             94                      NaN           0           36
# 738             59                      NaN          21         1092
# 739             92  Pasay City,Metro Manila         385        55669
#
#      rating_normal  rating_star  is_shopee_verified  is_official_shop
# 0              729         4.81                   1                 0
# 3              215         4.94                   1                 0
# 5                0         5.00                   0                 0
# 13            4793         4.77                   0                 0
# 17           24896         4.81                   1                 0
# ..             ...          ...                 ...               ...
# 724             47         4.46                   0                 0
# 735            185         4.83                   0                 0
# 737              1         4.89                   1                 0
# 738             63         4.75                   0                 0
# 739           1161         4.89                   0                 0
#
# [74 rows x 18 columns]

# %% [markdown]
# ### Lọc các bản ghi theo điều kiện phức

# %% [markdown]
# Điều kiện phức gồm từ 2 điều kiện đơn trở lên, các điều kiện đơn được để trong cặp dấu ngoặc đơn và được nối với nhau bởi các phép toán logic như: & (và), | (hoặc), ~ (phủ định).

# %%
# Ví dụ: Tìm các cửa hàng tham gia vào năm 2021 và có số lượng theo dõi >= 10000
df[(df['join_year'] == 2021) & (df['follower_count'] >= 10000)]
# Out:
#                pk_shop date_collected     shopid                   name  \
# 23   20210613418672464     2021-06-13  418672464                 xuxixi
# 326  20210621419954100     2021-06-21  419954100  Fall in love with you
# 365  20210628418672464     2021-06-28  418672464                 xuxixi
# 389  20210628373953071     2021-06-28  373953071             LK Shop ph
# 558  20210706382931801     2021-07-06  382931801  Stop And Shop Fashion
# 561  20210706373953071     2021-07-06  373953071             LK Shop ph
# 572  20210706418672464     2021-07-06  418672464     XuXi Apparel Store
# 738  20210706419954100     2021-07-06  419954100  Fall in love with you
#
#     join_month  join_day  join_year  item_count  follower_count response_time  \
# 23       April         7       2021         220           10180      09:26:55
# 326      April         9       2021         662           12783      09:01:18
# 365      April         7       2021         220           13768      10:23:37
# 389    January        16       2021         110           25191      10:17:41
# 558   February         3       2021         154           39669      09:25:24
# 561    January        16       2021         110           25806      10:08:14
# 572      April         7       2021         214           15614      10:23:31
# 738      April         9       2021         662           12968      09:33:28
#
#      response_rate                 shop_location  rating_bad  rating_good  \
# 23              95                           NaN           5         1771
# 326             86                           NaN          13          795
# 365             91                           NaN          16         3146
# 389             63  Valenzuela City,Metro Manila          86        19835
# 558             90                  Taytay,Rizal        1534        21058
# 561             67  Valenzuela City,Metro Manila          88        20858
# 572             89                           NaN          19         3792
# 738             59                           NaN          21         1092
#
#      rating_normal  rating_star  is_shopee_verified  is_official_shop
# 23              35         4.91                   1                 0
# 326             36         4.79                   1                 0
# 365             71         4.89                   1                 0
# 389            490         4.88                   0                 0
# 558           2422         4.45                   0                 0
# 561            520         4.88                   0                 0
# 572             85         4.89                   1                 0
# 738             63         4.75                   0                 0

# %% [markdown]
# ### Lọc các cột và các bản ghi theo điều kiện

# %%
# Hiển thị các thông tin về response_time, response_rate của các bản ghi có join_month là ‘April’
df[df['join_month']=='April'].filter(['response_time', 'response_rate'])
# Out:
#     response_time  response_rate
# 0        10:13:55             96
# 3        09:10:38             94
# 5        12:33:58             29
# 13       10:43:46             99
# 17       08:05:48             94
# ..            ...            ...
# 724      09:04:02             98
# 735      08:20:51             67
# 737      09:44:25             94
# 738      09:33:28             59
# 739      10:41:36             92
#
# [74 rows x 2 columns]

# %% [markdown]
# ## Lọc bản ghi sử dụng phương thức query

# %% [markdown]
# Phương thức truy vấn query giúp câu lệnh chạy nhanh hơn, các điều kiện được nối với nhau bởi các phép toán logic như: and (và), or (hoặc), not (phủ định) và được để trong một cặp dấu nháy kép.

# %%
# Ví dụ: Lọc các cửa hàng tham gia vào năm 2021 và có số lượng theo dõi >= 10000
df.query('(join_year == 2021) and (follower_count >= 10000)')
# Out:
#                pk_shop date_collected     shopid                   name  \
# 23   20210613418672464     2021-06-13  418672464                 xuxixi
# 326  20210621419954100     2021-06-21  419954100  Fall in love with you
# 365  20210628418672464     2021-06-28  418672464                 xuxixi
# 389  20210628373953071     2021-06-28  373953071             LK Shop ph
# 558  20210706382931801     2021-07-06  382931801  Stop And Shop Fashion
# 561  20210706373953071     2021-07-06  373953071             LK Shop ph
# 572  20210706418672464     2021-07-06  418672464     XuXi Apparel Store
# 738  20210706419954100     2021-07-06  419954100  Fall in love with you
#
#     join_month  join_day  join_year  item_count  follower_count response_time  \
# 23       April         7       2021         220           10180      09:26:55
# 326      April         9       2021         662           12783      09:01:18
# 365      April         7       2021         220           13768      10:23:37
# 389    January        16       2021         110           25191      10:17:41
# 558   February         3       2021         154           39669      09:25:24
# 561    January        16       2021         110           25806      10:08:14
# 572      April         7       2021         214           15614      10:23:31
# 738      April         9       2021         662           12968      09:33:28
#
#      response_rate                 shop_location  rating_bad  rating_good  \
# 23              95                           NaN           5         1771
# 326             86                           NaN          13          795
# 365             91                           NaN          16         3146
# 389             63  Valenzuela City,Metro Manila          86        19835
# 558             90                  Taytay,Rizal        1534        21058
# 561             67  Valenzuela City,Metro Manila          88        20858
# 572             89                           NaN          19         3792
# 738             59                           NaN          21         1092
#
#      rating_normal  rating_star  is_shopee_verified  is_official_shop
# 23              35         4.91                   1                 0
# 326             36         4.79                   1                 0
# 365             71         4.89                   1                 0
# 389            490         4.88                   0                 0
# 558           2422         4.45                   0                 0
# 561            520         4.88                   0                 0
# 572             85         4.89                   1                 0
# 738             63         4.75                   0                 0

# %% [markdown]
# # Gom nhóm dữ liệu

# %%
df.groupby(['join_year','shop_location'])[['rating_bad','rating_good']].max()
# Out:
#                                         rating_bad  rating_good
# join_year shop_location
# 2015      Taytay,Rizal                        2387       343050
# 2016      Bacoor,Cavite                        191        26249
#           Caloocan City,Metro Manila          1967       151821
#           Marikina City,Metro Manila            75         2550
#           Paranaque City,Metro Manila          722        33438
# ...                                            ...          ...
# 2021      Santa Cruz,Metro Manila                0          345
#           Silang,Cavite                          0           48
#           Taytay,Rizal                        1534        21058
#           Tondo I / Ii,Metro Manila             13         1717
#           Valenzuela City,Metro Manila          88        20858
#
# [97 rows x 2 columns]

# %% [markdown]
# # Thêm cột dữ liệu mới từ các cột dữ liệu đã có

# %% [markdown]
# ## Thêm các cột mới từ các cột có dữ liệu kiểu số

# %% [markdown]
# Ta có thể sử dụng các phép toán số học: +, -, *, /

# %%
# Tạo cột 'rating' tính điểm cho mỗi cửa hàng dựa vào thông tin các cột rating_bad, rating_good, rating_normal
# theo công thức sau: rating = rating_good *2 + rating_normal - rating_bad*3

df['rating'] = df['rating_good'] * 2 + df['rating_normal'] - df['rating_bad'] * 3
df
# Out:
#                pk_shop date_collected     shopid                  name  \
# 0    20210613254711738     2021-06-13  254711738          hello.may.ph
# 1    20210613314198143     2021-06-13  314198143       love.women.shop
# 2     2021061310377223     2021-06-13   10377223         R&O RedOrange
# 3     2021061321407329     2021-06-13   21407329           patriciacai
# 4     2021061311187885     2021-06-13   11187885  Little Market Manila
# ..                 ...            ...        ...                   ...
# 741  20210706449182992     2021-07-06  449182992     Yacent_thrift_Clo
# 742  20210706396605392     2021-07-06  396605392           Akistore.ph
# 743  20210706360379308     2021-07-06  360379308          Yzanice Shop
# 744   2021070629392066     2021-07-06   29392066        Clairecvc Shop
# 745   2021070625811092     2021-07-06   25811092           angelcity.💋
#
#     join_month  join_day  join_year  item_count  follower_count response_time  \
# 0        April        27       2020         446           17487      10:13:55
# 1    September        25       2020         263            8574      10:43:05
# 2    September        27       2016         209          660417      08:32:07
# 3        April        30       2017         165           18787      09:10:38
# 4      October        18       2016         467           67371      11:40:59
# ..         ...       ...        ...         ...             ...           ...
# 741        May        22       2021          16             115      08:45:30
# 742      March         3       2021          84              84      08:01:23
# 743   December        20       2020          78            5982      08:46:30
# 744     August         2       2017         964           44029      12:19:44
# 745       June        17       2017         272          868370      10:02:42
#
#      response_rate               shop_location  rating_bad  rating_good  \
# 0               96                         NaN         181        17510
# 1               73    San Nicolas,Metro Manila          78         2656
# 2               90     Pasay City,Metro Manila        4647      1071829
# 3               94        Binondo,Metro Manila          44        18959
# 4               89  Caloocan City,Metro Manila         680        39252
# ..             ...                         ...         ...          ...
# 741             86          Legazpi City,Albay           0           32
# 742             91                         NaN           1            9
# 743             96                         NaN          16          463
# 744             73        Binondo,Metro Manila        1960       103289
# 745             36     Pasay City,Metro Manila       13401       708666
#
#      rating_normal  rating_star  is_shopee_verified  is_official_shop   rating
# 0              729         4.81                   1                 0    35206
# 1              198         4.68                   0                 0     5276
# 2            18073         4.91                   1                 0  2147790
# 3              215         4.94                   1                 0    38001
# 4             2383         4.73                   1                 0    78847
# ..             ...          ...                 ...               ...      ...
# 741              0         5.00                   0                 0       64
# 742              0         4.60                   0                 0       15
# 743             16         4.75                   1                 0      894
# 744           3982         4.78                   0                 0   204680
# 745          30799         4.77                   0                 0  1407928
#
# [746 rows x 19 columns]

# %% [markdown]
# ## Thêm các cột mới từ các cột có dữ liệu kiểu chuỗi

# %% [markdown]
# Ta có thể sử dụng phép toán ghép chuỗi +Phép toán + dùng để nối các chuỗi lại với nhau, ta dùng hàm astype(str) để đổi một giá trị có kiểu bất kỳ về kiểu chuỗi.

# %%
# ghép 3 cột join_month, join_day, join_year thành cột mới có tên 'date' nhận giá trị có dạng: "join_month join_day,join_year"

df['date'] = df['join_month'] + " " + df['join_day'].astype(str) + "," + df['join_year'].astype(str)
df
# Out:
#                pk_shop date_collected     shopid                  name  \
# 0    20210613254711738     2021-06-13  254711738          hello.may.ph
# 1    20210613314198143     2021-06-13  314198143       love.women.shop
# 2     2021061310377223     2021-06-13   10377223         R&O RedOrange
# 3     2021061321407329     2021-06-13   21407329           patriciacai
# 4     2021061311187885     2021-06-13   11187885  Little Market Manila
# ..                 ...            ...        ...                   ...
# 741  20210706449182992     2021-07-06  449182992     Yacent_thrift_Clo
# 742  20210706396605392     2021-07-06  396605392           Akistore.ph
# 743  20210706360379308     2021-07-06  360379308          Yzanice Shop
# 744   2021070629392066     2021-07-06   29392066        Clairecvc Shop
# 745   2021070625811092     2021-07-06   25811092           angelcity.💋
#
#     join_month  join_day  join_year  item_count  follower_count response_time  \
# 0        April        27       2020         446           17487      10:13:55
# 1    September        25       2020         263            8574      10:43:05
# 2    September        27       2016         209          660417      08:32:07
# 3        April        30       2017         165           18787      09:10:38
# 4      October        18       2016         467           67371      11:40:59
# ..         ...       ...        ...         ...             ...           ...
# 741        May        22       2021          16             115      08:45:30
# 742      March         3       2021          84              84      08:01:23
# 743   December        20       2020          78            5982      08:46:30
# 744     August         2       2017         964           44029      12:19:44
# 745       June        17       2017         272          868370      10:02:42
#
#      response_rate               shop_location  rating_bad  rating_good  \
# 0               96                         NaN         181        17510
# 1               73    San Nicolas,Metro Manila          78         2656
# 2               90     Pasay City,Metro Manila        4647      1071829
# 3               94        Binondo,Metro Manila          44        18959
# 4               89  Caloocan City,Metro Manila         680        39252
# ..             ...                         ...         ...          ...
# 741             86          Legazpi City,Albay           0           32
# 742             91                         NaN           1            9
# 743             96                         NaN          16          463
# 744             73        Binondo,Metro Manila        1960       103289
# 745             36     Pasay City,Metro Manila       13401       708666
#
#      rating_normal  rating_star  is_shopee_verified  is_official_shop  \
# 0              729         4.81                   1                 0
# 1              198         4.68                   0                 0
# 2            18073         4.91                   1                 0
# 3              215         4.94                   1                 0
# 4             2383         4.73                   1                 0
# ..             ...          ...                 ...               ...
# 741              0         5.00                   0                 0
# 742              0         4.60                   0                 0
# 743             16         4.75                   1                 0
# 744           3982         4.78                   0                 0
# 745          30799         4.77                   0                 0
#
#       rating               date
# 0      35206      April 27,2020
# 1       5276  September 25,2020
# 2    2147790  September 27,2016
# 3      38001      April 30,2017
# 4      78847    October 18,2016
# ..       ...                ...
# 741       64        May 22,2021
# 742       15       March 3,2021
# 743      894   December 20,2020
# 744   204680      August 2,2017
# 745  1407928       June 17,2017
#
# [746 rows x 20 columns]

# %% [markdown]
# ## Thêm các cột mới theo điều kiện

# %%
# Thêm cột new có giá trị True nếu join_year = 2021 và False trong trường hợp còn lại.
df['new'] = df['join_year'] == 2021
df
# Out:
#                pk_shop date_collected     shopid                  name  \
# 0    20210613254711738     2021-06-13  254711738          hello.may.ph
# 1    20210613314198143     2021-06-13  314198143       love.women.shop
# 2     2021061310377223     2021-06-13   10377223         R&O RedOrange
# 3     2021061321407329     2021-06-13   21407329           patriciacai
# 4     2021061311187885     2021-06-13   11187885  Little Market Manila
# ..                 ...            ...        ...                   ...
# 741  20210706449182992     2021-07-06  449182992     Yacent_thrift_Clo
# 742  20210706396605392     2021-07-06  396605392           Akistore.ph
# 743  20210706360379308     2021-07-06  360379308          Yzanice Shop
# 744   2021070629392066     2021-07-06   29392066        Clairecvc Shop
# 745   2021070625811092     2021-07-06   25811092           angelcity.💋
#
#     join_month  join_day  join_year  item_count  follower_count response_time  \
# 0        April        27       2020         446           17487      10:13:55
# 1    September        25       2020         263            8574      10:43:05
# 2    September        27       2016         209          660417      08:32:07
# 3        April        30       2017         165           18787      09:10:38
# 4      October        18       2016         467           67371      11:40:59
# ..         ...       ...        ...         ...             ...           ...
# 741        May        22       2021          16             115      08:45:30
# 742      March         3       2021          84              84      08:01:23
# 743   December        20       2020          78            5982      08:46:30
# 744     August         2       2017         964           44029      12:19:44
# 745       June        17       2017         272          868370      10:02:42
#
#      ...               shop_location rating_bad  rating_good  rating_normal  \
# 0    ...                         NaN        181        17510            729
# 1    ...    San Nicolas,Metro Manila         78         2656            198
# 2    ...     Pasay City,Metro Manila       4647      1071829          18073
# 3    ...        Binondo,Metro Manila         44        18959            215
# 4    ...  Caloocan City,Metro Manila        680        39252           2383
# ..   ...                         ...        ...          ...            ...
# 741  ...          Legazpi City,Albay          0           32              0
# 742  ...                         NaN          1            9              0
# 743  ...                         NaN         16          463             16
# 744  ...        Binondo,Metro Manila       1960       103289           3982
# 745  ...     Pasay City,Metro Manila      13401       708666          30799
#
#      rating_star  is_shopee_verified  is_official_shop   rating  \
# 0           4.81                   1                 0    35206
# 1           4.68                   0                 0     5276
# 2           4.91                   1                 0  2147790
# 3           4.94                   1                 0    38001
# 4           4.73                   1                 0    78847
# ..           ...                 ...               ...      ...
# 741         5.00                   0                 0       64
# 742         4.60                   0                 0       15
# 743         4.75                   1                 0      894
# 744         4.78                   0                 0   204680
# 745         4.77                   0                 0  1407928
#
#                   date    new
# 0        April 27,2020  False
# 1    September 25,2020  False
# 2    September 27,2016  False
# 3        April 30,2017  False
# 4      October 18,2016  False
# ..                 ...    ...
# 741        May 22,2021   True
# 742       March 3,2021   True
# 743   December 20,2020  False
# 744      August 2,2017  False
# 745       June 17,2017  False
#
# [746 rows x 21 columns]

# %%
# Nếu có 2 lựa chọn ta sử dụng np.where
# Thêm cột rate có giá trị good nếu rating_good >= 50000,  bad trong trường hợp còn lại

import numpy as np
df['rate'] = np.where(df['rating_good'] >= 50000,'good','bad' )
df
# Out:
#                pk_shop date_collected     shopid                  name  \
# 0    20210613254711738     2021-06-13  254711738          hello.may.ph
# 1    20210613314198143     2021-06-13  314198143       love.women.shop
# 2     2021061310377223     2021-06-13   10377223         R&O RedOrange
# 3     2021061321407329     2021-06-13   21407329           patriciacai
# 4     2021061311187885     2021-06-13   11187885  Little Market Manila
# ..                 ...            ...        ...                   ...
# 741  20210706449182992     2021-07-06  449182992     Yacent_thrift_Clo
# 742  20210706396605392     2021-07-06  396605392           Akistore.ph
# 743  20210706360379308     2021-07-06  360379308          Yzanice Shop
# 744   2021070629392066     2021-07-06   29392066        Clairecvc Shop
# 745   2021070625811092     2021-07-06   25811092           angelcity.💋
#
#     join_month  join_day  join_year  item_count  follower_count response_time  \
# 0        April        27       2020         446           17487      10:13:55
# 1    September        25       2020         263            8574      10:43:05
# 2    September        27       2016         209          660417      08:32:07
# 3        April        30       2017         165           18787      09:10:38
# 4      October        18       2016         467           67371      11:40:59
# ..         ...       ...        ...         ...             ...           ...
# 741        May        22       2021          16             115      08:45:30
# 742      March         3       2021          84              84      08:01:23
# 743   December        20       2020          78            5982      08:46:30
# 744     August         2       2017         964           44029      12:19:44
# 745       June        17       2017         272          868370      10:02:42
#
#      ...  rating_bad rating_good  rating_normal  rating_star  \
# 0    ...         181       17510            729         4.81
# 1    ...          78        2656            198         4.68
# 2    ...        4647     1071829          18073         4.91
# 3    ...          44       18959            215         4.94
# 4    ...         680       39252           2383         4.73
# ..   ...         ...         ...            ...          ...
# 741  ...           0          32              0         5.00
# 742  ...           1           9              0         4.60
# 743  ...          16         463             16         4.75
# 744  ...        1960      103289           3982         4.78
# 745  ...       13401      708666          30799         4.77
#
#      is_shopee_verified  is_official_shop   rating               date    new  \
# 0                     1                 0    35206      April 27,2020  False
# 1                     0                 0     5276  September 25,2020  False
# 2                     1                 0  2147790  September 27,2016  False
# 3                     1                 0    38001      April 30,2017  False
# 4                     1                 0    78847    October 18,2016  False
# ..                  ...               ...      ...                ...    ...
# 741                   0                 0       64        May 22,2021   True
# 742                   0                 0       15       March 3,2021   True
# 743                   1                 0      894   December 20,2020  False
# 744                   0                 0   204680      August 2,2017  False
# 745                   0                 0  1407928       June 17,2017  False
#
#      rate
# 0     bad
# 1     bad
# 2    good
# 3     bad
# 4     bad
# ..    ...
# 741   bad
# 742   bad
# 743   bad
# 744  good
# 745  good
#
# [746 rows x 22 columns]

# %%
# Nếu có nhiều hơn 2 lựa chọn ta sử dụng np.select
# Thêm cột flag tặng cờ cho các cửa hàng, flag nhận các giá trị như sau:
# blue khi rating_good >= 30000 và rating_bad <= 100
# yellow khi 10000 <= rating_good < 30000 và 100 < rating_bad <= 1000
# red khi rating_good < 10000
# black đối với các trường hợp còn lại

conditions = [(df['rating_good'] >= 30000) & (df['rating_bad'] <= 100),
              (df['rating_good'] >= 10000) & (df['rating_good'] < 30000) & (df['rating_bad'] <= 1000) & (df['rating_bad'] > 100),
              (df['rating_good'] < 10000)]
choices = ['blue', 'yellow','red']
df['flag'] = np.select(conditions, choices, default='black')
df
# Out:
#                pk_shop date_collected     shopid                  name  \
# 0    20210613254711738     2021-06-13  254711738          hello.may.ph
# 1    20210613314198143     2021-06-13  314198143       love.women.shop
# 2     2021061310377223     2021-06-13   10377223         R&O RedOrange
# 3     2021061321407329     2021-06-13   21407329           patriciacai
# 4     2021061311187885     2021-06-13   11187885  Little Market Manila
# ..                 ...            ...        ...                   ...
# 741  20210706449182992     2021-07-06  449182992     Yacent_thrift_Clo
# 742  20210706396605392     2021-07-06  396605392           Akistore.ph
# 743  20210706360379308     2021-07-06  360379308          Yzanice Shop
# 744   2021070629392066     2021-07-06   29392066        Clairecvc Shop
# 745   2021070625811092     2021-07-06   25811092           angelcity.💋
#
#     join_month  join_day  join_year  item_count  follower_count response_time  \
# 0        April        27       2020         446           17487      10:13:55
# 1    September        25       2020         263            8574      10:43:05
# 2    September        27       2016         209          660417      08:32:07
# 3        April        30       2017         165           18787      09:10:38
# 4      October        18       2016         467           67371      11:40:59
# ..         ...       ...        ...         ...             ...           ...
# 741        May        22       2021          16             115      08:45:30
# 742      March         3       2021          84              84      08:01:23
# 743   December        20       2020          78            5982      08:46:30
# 744     August         2       2017         964           44029      12:19:44
# 745       June        17       2017         272          868370      10:02:42
#
#      ...  rating_good rating_normal  rating_star  is_shopee_verified  \
# 0    ...        17510           729         4.81                   1
# 1    ...         2656           198         4.68                   0
# 2    ...      1071829         18073         4.91                   1
# 3    ...        18959           215         4.94                   1
# 4    ...        39252          2383         4.73                   1
# ..   ...          ...           ...          ...                 ...
# 741  ...           32             0         5.00                   0
# 742  ...            9             0         4.60                   0
# 743  ...          463            16         4.75                   1
# 744  ...       103289          3982         4.78                   0
# 745  ...       708666         30799         4.77                   0
#
#      is_official_shop   rating               date    new  rate    flag
# 0                   0    35206      April 27,2020  False   bad  yellow
# 1                   0     5276  September 25,2020  False   bad     red
# 2                   0  2147790  September 27,2016  False  good   black
# 3                   0    38001      April 30,2017  False   bad   black
# 4                   0    78847    October 18,2016  False   bad   black
# ..                ...      ...                ...    ...   ...     ...
# 741                 0       64        May 22,2021   True   bad     red
# 742                 0       15       March 3,2021   True   bad     red
# 743                 0      894   December 20,2020  False   bad     red
# 744                 0   204680      August 2,2017  False  good   black
# 745                 0  1407928       June 17,2017  False  good   black
#
# [746 rows x 23 columns]

# %% [markdown]
# # Tách dữ liệu của một cột thành nhiều cột

# %% [markdown]
# ## Tách cột dữ liệu có kiểu chuỗi

# %% [markdown]
# Ta có thể sử dụng các phép toán tách chuỗi splitHàm str.split(‘Ký tự phân cách’) có tác dụng tách chuỗi ban đầu str thành các chuỗi con được ngăn cách nhau bởi ký tự phân cách

# %%
# Tách cột shop_location thành 2 cột District và City
df['District']=df['shop_location'].str.split(',').str[0]
df['City']=df['shop_location'].str.split(',').str[1]
df
# Out:
#                pk_shop date_collected     shopid                  name  \
# 0    20210613254711738     2021-06-13  254711738          hello.may.ph
# 1    20210613314198143     2021-06-13  314198143       love.women.shop
# 2     2021061310377223     2021-06-13   10377223         R&O RedOrange
# 3     2021061321407329     2021-06-13   21407329           patriciacai
# 4     2021061311187885     2021-06-13   11187885  Little Market Manila
# ..                 ...            ...        ...                   ...
# 741  20210706449182992     2021-07-06  449182992     Yacent_thrift_Clo
# 742  20210706396605392     2021-07-06  396605392           Akistore.ph
# 743  20210706360379308     2021-07-06  360379308          Yzanice Shop
# 744   2021070629392066     2021-07-06   29392066        Clairecvc Shop
# 745   2021070625811092     2021-07-06   25811092           angelcity.💋
#
#     join_month  join_day  join_year  item_count  follower_count response_time  \
# 0        April        27       2020         446           17487      10:13:55
# 1    September        25       2020         263            8574      10:43:05
# 2    September        27       2016         209          660417      08:32:07
# 3        April        30       2017         165           18787      09:10:38
# 4      October        18       2016         467           67371      11:40:59
# ..         ...       ...        ...         ...             ...           ...
# 741        May        22       2021          16             115      08:45:30
# 742      March         3       2021          84              84      08:01:23
# 743   December        20       2020          78            5982      08:46:30
# 744     August         2       2017         964           44029      12:19:44
# 745       June        17       2017         272          868370      10:02:42
#
#      ...  rating_star is_shopee_verified  is_official_shop   rating  \
# 0    ...         4.81                  1                 0    35206
# 1    ...         4.68                  0                 0     5276
# 2    ...         4.91                  1                 0  2147790
# 3    ...         4.94                  1                 0    38001
# 4    ...         4.73                  1                 0    78847
# ..   ...          ...                ...               ...      ...
# 741  ...         5.00                  0                 0       64
# 742  ...         4.60                  0                 0       15
# 743  ...         4.75                  1                 0      894
# 744  ...         4.78                  0                 0   204680
# 745  ...         4.77                  0                 0  1407928
#
#                   date    new  rate    flag       District          City
# 0        April 27,2020  False   bad  yellow            NaN           NaN
# 1    September 25,2020  False   bad     red    San Nicolas  Metro Manila
# 2    September 27,2016  False  good   black     Pasay City  Metro Manila
# 3        April 30,2017  False   bad   black        Binondo  Metro Manila
# 4      October 18,2016  False   bad   black  Caloocan City  Metro Manila
# ..                 ...    ...   ...     ...            ...           ...
# 741        May 22,2021   True   bad     red   Legazpi City         Albay
# 742       March 3,2021   True   bad     red            NaN           NaN
# 743   December 20,2020  False   bad     red            NaN           NaN
# 744      August 2,2017  False  good   black        Binondo  Metro Manila
# 745       June 17,2017  False  good   black     Pasay City  Metro Manila
#
# [746 rows x 25 columns]

# %% [markdown]
# ## Tách cột dữ liệu có kiểu ngày tháng

# %%
# Tách cột date_collected thành 3 cột Day, Month, Year
df['Day']=pd.to_datetime(df['date_collected'],format='%Y-%m-%d').dt.day
df['Month']=pd.to_datetime(df['date_collected'],format='%Y-%m-%d').dt.month
df['Year']=pd.to_datetime(df['date_collected'],format='%Y-%m-%d').dt.year
df
# Out:
#                pk_shop date_collected     shopid                  name  \
# 0    20210613254711738     2021-06-13  254711738          hello.may.ph
# 1    20210613314198143     2021-06-13  314198143       love.women.shop
# 2     2021061310377223     2021-06-13   10377223         R&O RedOrange
# 3     2021061321407329     2021-06-13   21407329           patriciacai
# 4     2021061311187885     2021-06-13   11187885  Little Market Manila
# ..                 ...            ...        ...                   ...
# 741  20210706449182992     2021-07-06  449182992     Yacent_thrift_Clo
# 742  20210706396605392     2021-07-06  396605392           Akistore.ph
# 743  20210706360379308     2021-07-06  360379308          Yzanice Shop
# 744   2021070629392066     2021-07-06   29392066        Clairecvc Shop
# 745   2021070625811092     2021-07-06   25811092           angelcity.💋
#
#     join_month  join_day  join_year  item_count  follower_count response_time  \
# 0        April        27       2020         446           17487      10:13:55
# 1    September        25       2020         263            8574      10:43:05
# 2    September        27       2016         209          660417      08:32:07
# 3        April        30       2017         165           18787      09:10:38
# 4      October        18       2016         467           67371      11:40:59
# ..         ...       ...        ...         ...             ...           ...
# 741        May        22       2021          16             115      08:45:30
# 742      March         3       2021          84              84      08:01:23
# 743   December        20       2020          78            5982      08:46:30
# 744     August         2       2017         964           44029      12:19:44
# 745       June        17       2017         272          868370      10:02:42
#
#      ...   rating               date    new  rate    flag       District  \
# 0    ...    35206      April 27,2020  False   bad  yellow            NaN
# 1    ...     5276  September 25,2020  False   bad     red    San Nicolas
# 2    ...  2147790  September 27,2016  False  good   black     Pasay City
# 3    ...    38001      April 30,2017  False   bad   black        Binondo
# 4    ...    78847    October 18,2016  False   bad   black  Caloocan City
# ..   ...      ...                ...    ...   ...     ...            ...
# 741  ...       64        May 22,2021   True   bad     red   Legazpi City
# 742  ...       15       March 3,2021   True   bad     red            NaN
# 743  ...      894   December 20,2020  False   bad     red            NaN
# 744  ...   204680      August 2,2017  False  good   black        Binondo
# 745  ...  1407928       June 17,2017  False  good   black     Pasay City
#
#              City  Day  Month  Year
# 0             NaN   13      6  2021
# 1    Metro Manila   13      6  2021
# 2    Metro Manila   13      6  2021
# 3    Metro Manila   13      6  2021
# 4    Metro Manila   13      6  2021
# ..            ...  ...    ...   ...
# 741         Albay    6      7  2021
# 742           NaN    6      7  2021
# 743           NaN    6      7  2021
# 744  Metro Manila    6      7  2021
# 745  Metro Manila    6      7  2021
#
# [746 rows x 28 columns]

# %% [markdown]
# ## Tách cột date_collected thành 3 cột Day, Month, Year

# %%
df['Day']=pd.to_datetime(df['date_collected'],format='%Y-%m-%d').dt.day
df['Month']=pd.to_datetime(df['date_collected'],format='%Y-%m-%d').dt.month
df['Year']=pd.to_datetime(df['date_collected'],format='%Y-%m-%d').dt.year
df
# Out:
#                pk_shop date_collected     shopid                  name  \
# 0    20210613254711738     2021-06-13  254711738          hello.may.ph
# 1    20210613314198143     2021-06-13  314198143       love.women.shop
# 2     2021061310377223     2021-06-13   10377223         R&O RedOrange
# 3     2021061321407329     2021-06-13   21407329           patriciacai
# 4     2021061311187885     2021-06-13   11187885  Little Market Manila
# ..                 ...            ...        ...                   ...
# 741  20210706449182992     2021-07-06  449182992     Yacent_thrift_Clo
# 742  20210706396605392     2021-07-06  396605392           Akistore.ph
# 743  20210706360379308     2021-07-06  360379308          Yzanice Shop
# 744   2021070629392066     2021-07-06   29392066        Clairecvc Shop
# 745   2021070625811092     2021-07-06   25811092           angelcity.💋
#
#     join_month  join_day  join_year  item_count  follower_count response_time  \
# 0        April        27       2020         446           17487      10:13:55
# 1    September        25       2020         263            8574      10:43:05
# 2    September        27       2016         209          660417      08:32:07
# 3        April        30       2017         165           18787      09:10:38
# 4      October        18       2016         467           67371      11:40:59
# ..         ...       ...        ...         ...             ...           ...
# 741        May        22       2021          16             115      08:45:30
# 742      March         3       2021          84              84      08:01:23
# 743   December        20       2020          78            5982      08:46:30
# 744     August         2       2017         964           44029      12:19:44
# 745       June        17       2017         272          868370      10:02:42
#
#      ...   rating               date    new  rate    flag       District  \
# 0    ...    35206      April 27,2020  False   bad  yellow            NaN
# 1    ...     5276  September 25,2020  False   bad     red    San Nicolas
# 2    ...  2147790  September 27,2016  False  good   black     Pasay City
# 3    ...    38001      April 30,2017  False   bad   black        Binondo
# 4    ...    78847    October 18,2016  False   bad   black  Caloocan City
# ..   ...      ...                ...    ...   ...     ...            ...
# 741  ...       64        May 22,2021   True   bad     red   Legazpi City
# 742  ...       15       March 3,2021   True   bad     red            NaN
# 743  ...      894   December 20,2020  False   bad     red            NaN
# 744  ...   204680      August 2,2017  False  good   black        Binondo
# 745  ...  1407928       June 17,2017  False  good   black     Pasay City
#
#              City  Day  Month  Year
# 0             NaN   13      6  2021
# 1    Metro Manila   13      6  2021
# 2    Metro Manila   13      6  2021
# 3    Metro Manila   13      6  2021
# 4    Metro Manila   13      6  2021
# ..            ...  ...    ...   ...
# 741         Albay    6      7  2021
# 742           NaN    6      7  2021
# 743           NaN    6      7  2021
# 744  Metro Manila    6      7  2021
# 745  Metro Manila    6      7  2021
#
# [746 rows x 28 columns]
