# %% [markdown]
#  ## Pandas – 1  [Bài tập] Phân tích trên bộ dữ liệu GPD00000

# %% [markdown]
# ### Yêu cầu
#
# - Đọc bộ dữ liệu, cho biết số dòng, số cột và kiểu dữ liệu của các thuộc tính.

# %%
# Nhập thư viện

import pandas as pd
import numpy as np

# %%
# ĐỌc dữ liệu

df = pd.read_csv('GDPlist.csv', encoding='unicode-escape')

#xem 5 dòng đầu dữ liệu
df.head()
# Out:
#         Country      Continent  GDP (millions of US$)
# 0   Afghanistan           Asia                  18181
# 1       Albania         Europe                  12847
# 2       Algeria         Africa                 190709
# 3        Angola         Africa                 100948
# 4     Argentina  South America                 447644

# %%
# số dòng, số cột của dữ liệu

df.shape
# Out:
# (125, 3)

# %%
# kiểu dữ liệu của thuộc tính

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                125 non-null    object
#  1   Continent              125 non-null    object
#  2   GDP (millions of US$)  125 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 3.1+ KB

# %% [markdown]
# #### Việt hóa tên các cột trong bảng dữ liệu: Country 🡪 Nuoc; Continent 🡪 Chauluc; GDP (millions of US$) 🡪 GDP (trieu $)

# %%
# đổi tên cột

df = df.rename(columns= {'Country':'Nuoc', 'Continent':'Chauluc', 'GDP (millions of US$)':'GDP(trieu)'})
df.head()
# Out:
#            Nuoc        Chauluc  GDP(trieu)
# 0   Afghanistan           Asia       18181
# 1       Albania         Europe       12847
# 2       Algeria         Africa      190709
# 3        Angola         Africa      100948
# 4     Argentina  South America      447644

# %% [markdown]
# #### Chèn thêm một cột “Thanhpho” vào sau cột “Nuoc”, giá trị ban đầu là giá trị của cột “Nuoc”

# %%
# Dùng phương thức insert với tham số thứ 3 là giá trị cần thêm được xác định bằng phương thức loc: df.loc[:,’Nuoc’] 

df.insert(1, 'Thanhpho', pd.Series(df.loc[:, 'Nuoc'], index=df.index))
df.head()
# Out:
#            Nuoc      Thanhpho        Chauluc  GDP(trieu)
# 0   Afghanistan   Afghanistan           Asia       18181
# 1       Albania       Albania         Europe       12847
# 2       Algeria       Algeria         Africa      190709
# 3        Angola        Angola         Africa      100948
# 4     Argentina     Argentina  South America      447644

# %% [markdown]
# #### Trong cột Thanhpho, thay giá trị Vietnam thành Hanoi; Làm tương tự với các nước còn lại.

# %%
df['Thanhpho'].replace('Vietnam', 'Hanoi', inplace=True)
df.tail()
# Out:
#             Nuoc     Thanhpho        Chauluc  GDP(trieu)
# 120   Uzbekistan   Uzbekistan           Asia       45353
# 121    Venezuela    Venezuela  South America      315841
# 122      Vietnam      Vietnam           Asia      122722
# 123        Yemen        Yemen         Africa       33675
# 124       Zambia       Zambia         Africa       19206

# %%
df['Thanhpho'] = df['Thanhpho'].replace({'Vietnam': 'Hanoi'})
df.tail()
# Out:
#             Nuoc     Thanhpho        Chauluc  GDP(trieu)
# 120   Uzbekistan   Uzbekistan           Asia       45353
# 121    Venezuela    Venezuela  South America      315841
# 122      Vietnam      Vietnam           Asia      122722
# 123        Yemen        Yemen         Africa       33675
# 124       Zambia       Zambia         Africa       19206

# %% [markdown]
# #### Xóa các bản ghi có Chauluc là ‘Asia’

# %% [markdown]
# Dùng phương thức drop xóa các dòng, với tham số đầu tiên chỉ số của các dòng được xác định bởi phương thức loc: df.loc[df.ChauLuc == ‘Asia’].index

# %%
df1 = df.loc[df['Chauluc'] == 'Asia']
df1
# Out:
#                       Nuoc               Thanhpho Chauluc  GDP(trieu)
# 0              Afghanistan            Afghanistan    Asia       18181
# 8                  Bahrain                Bahrain    Asia       26108
# 9               Bangladesh             Bangladesh    Asia      113032
# 16                  Brunei                 Brunei    Asia       15533
# 18                   Burma                  Burma    Asia       51925
# 19                Cambodia               Cambodia    Asia       12861
# 23                   China                  China    Asia     7298147
# 49               Hong Kong              Hong Kong    Asia      243302
# 52                   India                  India    Asia     1676143
# 53               Indonesia              Indonesia    Asia      845680
# 54                    Iran                   Iran    Asia      482445
# 55                    Iraq                   Iraq    Asia      115388
# ...

# %%
df.drop(df1, axis=0, inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df.drop(df1, axis=0, inplace=True)
#       2 df
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
# ...

# %% [markdown]
# #### Xóa các bản ghi có GDP < 300000

# %%
df2 = df[df['GDP(trieu)'] < 300000]
df2
# Out:
#              Nuoc      Thanhpho        Chauluc  GDP(trieu)
# 0     Afghanistan   Afghanistan           Asia       18181
# 1         Albania       Albania         Europe       12847
# 2         Algeria       Algeria         Africa      190709
# 3          Angola        Angola         Africa      100948
# 7      Azerbaijan    Azerbaijan         Europe       62321
# ..            ...           ...            ...         ...
# 119       Uruguay       Uruguay  South America       46872
# 120    Uzbekistan    Uzbekistan           Asia       45353
# 122       Vietnam       Vietnam           Asia      122722
# 123         Yemen         Yemen         Africa       33675
# 124        Zambia        Zambia         Africa       19206
#
# [90 rows x 4 columns]
